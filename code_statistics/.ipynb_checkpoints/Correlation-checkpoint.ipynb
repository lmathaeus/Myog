# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/nome.csv', sep=',', index_col=0)
df.head(5)
# Out:
#                                       name  order_id  customer_id  \
# 265373        Lombo Suino Fresco Fat Bd Kg      9991         7927
# 79454        Feijao Pedretti Ouro Tp 1 1kg      5434         7927
# 79453             Molho Tom Fugini Sc 340g      5434         7927
# 79452   Arroz Rosalito Ext Premium Tp1 2kg      5434         7927
# 79451                Qjo Muss Aurora Pd Kg      5434         7927
#
#         int_itens_comp
# 265373            3203
# 79454             2350
# 79453             3624
# 79452              441
# 79451             4447

# %%
# quantidade de ítens comprados por cliente
grup = df.groupby(by='customer_id').name.value_counts()
#grup.to_csv('../data/Itensbyclient.csv')
grup
# Out:
# customer_id  name
# 7927         Acucar Ref Uniao 1kg                  11
#              Iog Vigor Grego 100g                  10
#              Lava Roupa Po Omo Lav Perf Cx 800g     8
#              Oleo Soja Liza Pet 900ml               8
#              Refrig Antarc Soda 600ml               8
#                                                    ..
# 61661        Lava Roupa Po Tixan Cx 1kg             2
#              Pano Limppano Furatto C/5              2
#              Silic Auto Monza 100ml                 2
#              Marg Qualy Cremosa 500g                1
#              Odoriz Amb Glade Aero 360ml            1
# Name: name, Length: 138977, dtype: int64

# %%
# os 10 ítens mais vendidos
mais_vendidos = df['name'].value_counts()[:10]
mais_vendidos
# Out:
# Refresco Tang 25g               5392
# Lava Louca Liq Ype 500ml        5129
# Refresco Sukest 30g Faz 1l      4410
# Molho Tom Predilecta Sc 340g    2822
# Tomate Pizzadoro Kg             2745
# Cebola Kg                       2711
# Batata Kg                       2639
# Leite Lv Jussara 1l             2248
# Mac Basilar Semolado 500g       2195
# Pao Frances Kg                  2091
# Name: name, dtype: int64

# %%
# nomes dos produtos mais pedidos
prods = [s.strip() for s in mais_vendidos.index.tolist()]
prods
# Out:
# ['Refresco Tang 25g',
#  'Lava Louca Liq Ype 500ml',
#  'Refresco Sukest 30g Faz 1l',
#  'Molho Tom Predilecta Sc 340g',
#  'Tomate Pizzadoro Kg',
#  'Cebola Kg',
#  'Batata Kg',
#  'Leite Lv Jussara 1l',
#  'Mac Basilar Semolado 500g',
#  'Pao Frances Kg']

# %%
# plotagem do gráfico 
plt.figure(figsize=(14,7))
g=sns.barplot(x = prods , y = mais_vendidos,palette='YlGn_r')
g.set_xticklabels(prods,rotation=270)
g.set_ylabel('Número de pedidos');
g.set_title('PRODUTOS MAIS VENDIDOS');
plt.show()

# %%
# primeira forma de preencher a matriz com zero para os valores faltantes
descricao_por_id = grup.unstack().fillna(0)
descricao_por_id.head()
# Out:
# name         Abacate Kg  Abacaxi Calda Ole Rodelas 400g  \
# customer_id
# 7927                0.0                             0.0
# 7952                0.0                             0.0
# 8037                0.0                             0.0
# 8079                0.0                             0.0
# 8086                0.0                             0.0
#
# name         Abacaxi Calda Predilecta 400g  Abacaxi Hawai Un  \
# customer_id
# 7927                                   0.0               0.0
# 7952                                   0.0               0.0
# 8037                                   0.0               0.0
# 8079                                   0.0               0.0
# 8086                                   1.0               0.0
#
# name         Abacaxi Pedaco Kg  Abacaxi Perola Un  Abacaxi Proc Kg  \
# customer_id
# 7927                       0.0                0.0              0.0
# 7952                       0.0                0.0              0.0
# 8037                       0.0                0.0              0.0
# 8079                       0.0                0.0              0.0
# 8086                       0.0                0.0              0.0
#
# name         Abobora Cabotia Cort Kg  Abobora Cabotia Int Kg  \
# customer_id
# 7927                             0.0                     0.0
# 7952                             0.0                     0.0
# 8037                             0.0                     0.0
# 8079                             0.0                     0.0
# 8086                             0.0                     0.0
#
# name         Abobora Madura Seca Cort Kg  ...  Whisky Johnnie Walker 1l  \
# customer_id                               ...
# 7927                                 0.0  ...                       0.0
# 7952                                 0.0  ...                       0.0
# 8037                                 0.0  ...                       0.0
# 8079                                 0.0  ...                       0.0
# 8086                                 0.0  ...                       0.0
#
# name         Whisky Natu Nobilis Nacional 1l  Whisky Old Eight Nacional 1l  \
# customer_id
# 7927                                     0.0                           0.0
# 7952                                     0.0                           0.0
# 8037                                     0.0                           0.0
# 8079                                     0.0                           0.0
# 8086                                     0.0                           0.0
#
# name         Wrap Wick Bold Ta Pronto 300g  Xarope Groselha Asteca 500ml  \
# customer_id
# 7927                                   0.0                           0.0
# 7952                                   0.0                           0.0
# 8037                                   0.0                           0.0
# 8079                                   0.0                           0.0
# 8086                                   0.0                           1.0
#
# name         Xarope Groselha Asteca 900ml  Xarope Groselha Primor 1l  \
# customer_id
# 7927                                  0.0                        0.0
# 7952                                  0.0                        0.0
# 8037                                  0.0                        0.0
# 8079                                  0.0                        0.0
# 8086                                  0.0                        0.0
#
# name         Xicara Cha Duralex Astral Un  Yakissoba Frango Kg  \
# customer_id
# 7927                                  0.0                  0.0
# 7952                                  0.0                  0.0
# 8037                                  0.0                  0.0
# 8079                                  0.0                  0.0
# 8086                                  0.0                  0.0
#
# name         Yakissoba Sadia 600g
# customer_id
# 7927                          0.0
# 7952                          0.0
# 8037                          0.0
# 8079                          0.0
# 8086                          0.0
#
# [5 rows x 5579 columns]

# %%
# segunda forma de preencher a matriz com zero para os valores faltantes
#os itens de cada compra
pred = pd.crosstab(df['customer_id'],df['name'])
pred = pd.DataFrame(pred)
pred.head(5)
# Out:
# name         Abacate Kg  Abacaxi Calda Ole Rodelas 400g  \
# customer_id
# 7927                  0                               0
# 7952                  0                               0
# 8037                  0                               0
# 8079                  0                               0
# 8086                  0                               0
#
# name         Abacaxi Calda Predilecta 400g  Abacaxi Hawai Un  \
# customer_id
# 7927                                     0                 0
# 7952                                     0                 0
# 8037                                     0                 0
# 8079                                     0                 0
# 8086                                     1                 0
#
# name         Abacaxi Pedaco Kg  Abacaxi Perola Un  Abacaxi Proc Kg  \
# customer_id
# 7927                         0                  0                0
# 7952                         0                  0                0
# 8037                         0                  0                0
# 8079                         0                  0                0
# 8086                         0                  0                0
#
# name         Abobora Cabotia Cort Kg  Abobora Cabotia Int Kg  \
# customer_id
# 7927                               0                       0
# 7952                               0                       0
# 8037                               0                       0
# 8079                               0                       0
# 8086                               0                       0
#
# name         Abobora Madura Seca Cort Kg  ...  Whisky Johnnie Walker 1l  \
# customer_id                               ...
# 7927                                   0  ...                         0
# 7952                                   0  ...                         0
# 8037                                   0  ...                         0
# 8079                                   0  ...                         0
# 8086                                   0  ...                         0
#
# name         Whisky Natu Nobilis Nacional 1l  Whisky Old Eight Nacional 1l  \
# customer_id
# 7927                                       0                             0
# 7952                                       0                             0
# 8037                                       0                             0
# 8079                                       0                             0
# 8086                                       0                             0
#
# name         Wrap Wick Bold Ta Pronto 300g  Xarope Groselha Asteca 500ml  \
# customer_id
# 7927                                     0                             0
# 7952                                     0                             0
# 8037                                     0                             0
# 8079                                     0                             0
# 8086                                     0                             1
#
# name         Xarope Groselha Asteca 900ml  Xarope Groselha Primor 1l  \
# customer_id
# 7927                                    0                          0
# 7952                                    0                          0
# 8037                                    0                          0
# 8079                                    0                          0
# 8086                                    0                          0
#
# name         Xicara Cha Duralex Astral Un  Yakissoba Frango Kg  \
# customer_id
# 7927                                    0                    0
# 7952                                    0                    0
# 8037                                    0                    0
# 8079                                    0                    0
# 8086                                    0                    0
#
# name         Yakissoba Sadia 600g
# customer_id
# 7927                            0
# 7952                            0
# 8037                            0
# 8079                            0
# 8086                            0
#
# [5 rows x 5579 columns]

# %%
# analisando a correlação dos produtos
correlation = pred.corr()
correlation
# Out:
# name                            Abacate Kg  Abacaxi Calda Ole Rodelas 400g  \
# name
# Abacate Kg                        1.000000                       -0.000051
# Abacaxi Calda Ole Rodelas 400g   -0.000051                        1.000000
# Abacaxi Calda Predilecta 400g     0.021790                       -0.003979
# Abacaxi Hawai Un                  0.262331                        0.015087
# Abacaxi Pedaco Kg                 0.008511                       -0.008952
# ...                                    ...                             ...
# Xarope Groselha Asteca 900ml     -0.020532                       -0.009341
# Xarope Groselha Primor 1l        -0.006911                       -0.003144
# Xicara Cha Duralex Astral Un     -0.006911                       -0.003144
# Yakissoba Frango Kg              -0.006911                       -0.003144
# Yakissoba Sadia 600g             -0.010426                       -0.004743
#
# name                            Abacaxi Calda Predilecta 400g  \
# name
# Abacate Kg                                           0.021790
# Abacaxi Calda Ole Rodelas 400g                      -0.003979
# Abacaxi Calda Predilecta 400g                        1.000000
# Abacaxi Hawai Un                                    -0.008046
# Abacaxi Pedaco Kg                                   -0.003602
# ...                                                       ...
# Xarope Groselha Asteca 900ml                        -0.003759
# Xarope Groselha Primor 1l                           -0.001265
# Xicara Cha Duralex Astral Un                        -0.001265
# Yakissoba Frango Kg                                 -0.001265
# Yakissoba Sadia 600g                                -0.001909
#
# name                            Abacaxi Hawai Un  Abacaxi Pedaco Kg  \
# name
# Abacate Kg                              0.262331           0.008511
# Abacaxi Calda Ole Rodelas 400g          0.015087          -0.008952
# Abacaxi Calda Predilecta 400g          -0.008046          -0.003602
# Abacaxi Hawai Un                        1.000000           0.016103
# Abacaxi Pedaco Kg                       0.016103           1.000000
# ...                                          ...                ...
# Xarope Groselha Asteca 900ml            0.008406          -0.008458
# Xarope Groselha Primor 1l              -0.006359          -0.002847
# Xicara Cha Duralex Astral Un            0.032691          -0.002847
# Yakissoba Frango Kg                    -0.006359          -0.002847
# Yakissoba Sadia 600g                    0.002189          -0.004295
#
# name                            Abacaxi Perola Un  Abacaxi Proc Kg  \
# name
# Abacate Kg                               0.626934        -0.006911
# Abacaxi Calda Ole Rodelas 400g          -0.017102        -0.003144
# Abacaxi Calda Predilecta 400g           -0.010818        -0.001265
# Abacaxi Hawai Un                         0.257414        -0.006359
# Abacaxi Pedaco Kg                        0.061502         0.435573
# ...                                           ...              ...
# Xarope Groselha Asteca 900ml             0.012657        -0.002971
# Xarope Groselha Primor 1l               -0.008550        -0.001000
# Xicara Cha Duralex Astral Un             0.078559        -0.001000
# Yakissoba Frango Kg                      0.013227        -0.001000
# Yakissoba Sadia 600g                     0.006813        -0.001509
#
# name                            Abobora Cabotia Cort Kg  \
# name
# Abacate Kg                                     0.251832
# Abacaxi Calda Ole Rodelas 400g                 0.038672
# Abacaxi Calda Predilecta 400g                 -0.008626
# Abacaxi Hawai Un                               0.108033
# Abacaxi Pedaco Kg                              0.127112
# ...                                                 ...
# Xarope Groselha Asteca 900ml                   0.038208
# Xarope Groselha Primor 1l                     -0.006818
# Xicara Cha Duralex Astral Un                  -0.006818
# Yakissoba Frango Kg                           -0.006818
# Yakissoba Sadia 600g                          -0.010285
#
# name                            Abobora Cabotia Int Kg  \
# name
# Abacate Kg                                    0.290721
# Abacaxi Calda Ole Rodelas 400g                0.039878
# Abacaxi Calda Predilecta 400g                -0.009329
# Abacaxi Hawai Un                              0.131497
# Abacaxi Pedaco Kg                            -0.003422
# ...                                                ...
# Xarope Groselha Asteca 900ml                  0.006134
# Xarope Groselha Primor 1l                    -0.007373
# Xicara Cha Duralex Astral Un                 -0.007373
# Yakissoba Frango Kg                          -0.007373
# Yakissoba Sadia 600g                         -0.011122
#
# name                            Abobora Madura Seca Cort Kg  ...  \
# name                                                         ...
# Abacate Kg                                         0.169026  ...
# Abacaxi Calda Ole Rodelas 400g                     0.011110  ...
# Abacaxi Calda Predilecta 400g                     -0.007153  ...
# Abacaxi Hawai Un                                   0.052692  ...
# Abacaxi Pedaco Kg                                 -0.006706  ...
# ...                                                     ...  ...
# Xarope Groselha Asteca 900ml                      -0.016796  ...
# Xarope Groselha Primor 1l                         -0.005654  ...
# Xicara Cha Duralex Astral Un                      -0.005654  ...
# Yakissoba Frango Kg                               -0.005654  ...
# Yakissoba Sadia 600g                              -0.008528  ...
#
# name                            Whisky Johnnie Walker 1l  \
# name
# Abacate Kg                                     -0.009779
# Abacaxi Calda Ole Rodelas 400g                  0.154604
# Abacaxi Calda Predilecta 400g                  -0.001790
# Abacaxi Hawai Un                                0.018629
# Abacaxi Pedaco Kg                              -0.004028
# ...                                                  ...
# Xarope Groselha Asteca 900ml                   -0.004204
# Xarope Groselha Primor 1l                      -0.001415
# Xicara Cha Duralex Astral Un                   -0.001415
# Yakissoba Frango Kg                            -0.001415
# Yakissoba Sadia 600g                           -0.002134
#
# name                            Whisky Natu Nobilis Nacional 1l  \
# name
# Abacate Kg                                            -0.006911
# Abacaxi Calda Ole Rodelas 400g                        -0.003144
# Abacaxi Calda Predilecta 400g                         -0.001265
# Abacaxi Hawai Un                                      -0.006359
# Abacaxi Pedaco Kg                                     -0.002847
# ...                                                         ...
# Xarope Groselha Asteca 900ml                          -0.002971
# Xarope Groselha Primor 1l                             -0.001000
# Xicara Cha Duralex Astral Un                          -0.001000
# Yakissoba Frango Kg                                   -0.001000
# Yakissoba Sadia 600g                                  -0.001509
#
# name                            Whisky Old Eight Nacional 1l  \
# name
# Abacate Kg                                         -0.009779
# Abacaxi Calda Ole Rodelas 400g                     -0.004449
# Abacaxi Calda Predilecta 400g                      -0.001790
# Abacaxi Hawai Un                                   -0.008997
# Abacaxi Pedaco Kg                                  -0.004028
# ...                                                      ...
# Xarope Groselha Asteca 900ml                       -0.004204
# Xarope Groselha Primor 1l                          -0.001415
# Xicara Cha Duralex Astral Un                       -0.001415
# Yakissoba Frango Kg                                -0.001415
# Yakissoba Sadia 600g                               -0.002134
#
# name                            Wrap Wick Bold Ta Pronto 300g  \
# name
# Abacate Kg                                           0.034495
# Abacaxi Calda Ole Rodelas 400g                      -0.006298
# Abacaxi Calda Predilecta 400g                       -0.002534
# Abacaxi Hawai Un                                     0.026372
# Abacaxi Pedaco Kg                                   -0.005702
# ...                                                       ...
# Xarope Groselha Asteca 900ml                        -0.005951
# Xarope Groselha Primor 1l                           -0.002003
# Xicara Cha Duralex Astral Un                        -0.002003
# Yakissoba Frango Kg                                  0.499249
# Yakissoba Sadia 600g                                -0.003022
#
# name                            Xarope Groselha Asteca 500ml  \
# name
# Abacate Kg                                          0.004302
# Abacaxi Calda Ole Rodelas 400g                      0.041408
# Abacaxi Calda Predilecta 400g                       0.070327
# Abacaxi Hawai Un                                   -0.005609
# Abacaxi Pedaco Kg                                   0.093219
# ...                                                      ...
# Xarope Groselha Asteca 900ml                        0.071736
# Xarope Groselha Primor 1l                          -0.003796
# Xicara Cha Duralex Astral Un                       -0.003796
# Yakissoba Frango Kg                                -0.003796
# Yakissoba Sadia 600g                               -0.005727
#
# name                            Xarope Groselha Asteca 900ml  \
# name
# Abacate Kg                                         -0.020532
# Abacaxi Calda Ole Rodelas 400g                     -0.009341
# Abacaxi Calda Predilecta 400g                      -0.003759
# Abacaxi Hawai Un                                    0.008406
# Abacaxi Pedaco Kg                                  -0.008458
# ...                                                      ...
# Xarope Groselha Asteca 900ml                        1.000000
# Xarope Groselha Primor 1l                          -0.002971
# Xicara Cha Duralex Astral Un                       -0.002971
# Yakissoba Frango Kg                                -0.002971
# Yakissoba Sadia 600g                                0.153851
#
# name                            Xarope Groselha Primor 1l  \
# name
# Abacate Kg                                      -0.006911
# Abacaxi Calda Ole Rodelas 400g                  -0.003144
# Abacaxi Calda Predilecta 400g                   -0.001265
# Abacaxi Hawai Un                                -0.006359
# Abacaxi Pedaco Kg                               -0.002847
# ...                                                   ...
# Xarope Groselha Asteca 900ml                    -0.002971
# Xarope Groselha Primor 1l                        1.000000
# Xicara Cha Duralex Astral Un                    -0.001000
# Yakissoba Frango Kg                             -0.001000
# Yakissoba Sadia 600g                            -0.001509
#
# name                            Xicara Cha Duralex Astral Un  \
# name
# Abacate Kg                                         -0.006911
# Abacaxi Calda Ole Rodelas 400g                     -0.003144
# Abacaxi Calda Predilecta 400g                      -0.001265
# Abacaxi Hawai Un                                    0.032691
# Abacaxi Pedaco Kg                                  -0.002847
# ...                                                      ...
# Xarope Groselha Asteca 900ml                       -0.002971
# Xarope Groselha Primor 1l                          -0.001000
# Xicara Cha Duralex Astral Un                        1.000000
# Yakissoba Frango Kg                                -0.001000
# Yakissoba Sadia 600g                               -0.001509
#
# name                            Yakissoba Frango Kg  Yakissoba Sadia 600g
# name
# Abacate Kg                                -0.006911             -0.010426
# Abacaxi Calda Ole Rodelas 400g            -0.003144             -0.004743
# Abacaxi Calda Predilecta 400g             -0.001265             -0.001909
# Abacaxi Hawai Un                          -0.006359              0.002189
# Abacaxi Pedaco Kg                         -0.002847             -0.004295
# ...                                             ...                   ...
# Xarope Groselha Asteca 900ml              -0.002971              0.153851
# Xarope Groselha Primor 1l                 -0.001000             -0.001509
# Xicara Cha Duralex Astral Un              -0.001000             -0.001509
# Yakissoba Frango Kg                        1.000000             -0.001509
# Yakissoba Sadia 600g                      -0.001509              1.000000
#
# [5579 rows x 5579 columns]

# %%
#retirando a descrição nominal das colunas(“descricao”)
descricao_por_id = pd.DataFrame(data= descricao_por_id.values, columns=descricao_por_id.columns.values.tolist(), index=descricao_por_id.index)
descricao_por_id
# Out:
#              Abacate Kg  Abacaxi Calda Ole Rodelas 400g  \
# customer_id
# 7927                0.0                             0.0
# 7952                0.0                             0.0
# 8037                0.0                             0.0
# 8079                0.0                             0.0
# 8086                0.0                             0.0
# ...                 ...                             ...
# 61625               2.0                             0.0
# 61631               0.0                             0.0
# 61640               0.0                             0.0
# 61643               0.0                             0.0
# 61661               0.0                             0.0
#
#              Abacaxi Calda Predilecta 400g  Abacaxi Hawai Un  \
# customer_id
# 7927                                   0.0               0.0
# 7952                                   0.0               0.0
# 8037                                   0.0               0.0
# 8079                                   0.0               0.0
# 8086                                   1.0               0.0
# ...                                    ...               ...
# 61625                                  0.0               2.0
# 61631                                  0.0               0.0
# 61640                                  0.0               0.0
# 61643                                  0.0               0.0
# 61661                                  0.0               0.0
#
#              Abacaxi Pedaco Kg  Abacaxi Perola Un  Abacaxi Proc Kg  \
# customer_id
# 7927                       0.0                0.0              0.0
# 7952                       0.0                0.0              0.0
# 8037                       0.0                0.0              0.0
# 8079                       0.0                0.0              0.0
# 8086                       0.0                0.0              0.0
# ...                        ...                ...              ...
# 61625                      0.0                1.0              0.0
# 61631                      0.0                1.0              0.0
# 61640                      0.0                0.0              0.0
# 61643                      0.0                0.0              0.0
# 61661                      0.0                0.0              0.0
#
#              Abobora Cabotia Cort Kg  Abobora Cabotia Int Kg  \
# customer_id
# 7927                             0.0                     0.0
# 7952                             0.0                     0.0
# 8037                             0.0                     0.0
# 8079                             0.0                     0.0
# 8086                             0.0                     0.0
# ...                              ...                     ...
# 61625                            0.0                     0.0
# 61631                            0.0                     0.0
# 61640                            0.0                     2.0
# 61643                            0.0                     0.0
# 61661                            0.0                     0.0
#
#              Abobora Madura Seca Cort Kg  ...  Whisky Johnnie Walker 1l  \
# customer_id                               ...
# 7927                                 0.0  ...                       0.0
# 7952                                 0.0  ...                       0.0
# 8037                                 0.0  ...                       0.0
# 8079                                 0.0  ...                       0.0
# 8086                                 0.0  ...                       0.0
# ...                                  ...  ...                       ...
# 61625                                1.0  ...                       0.0
# 61631                                0.0  ...                       0.0
# 61640                                2.0  ...                       0.0
# 61643                                0.0  ...                       0.0
# 61661                                0.0  ...                       0.0
#
#              Whisky Natu Nobilis Nacional 1l  Whisky Old Eight Nacional 1l  \
# customer_id
# 7927                                     0.0                           0.0
# 7952                                     0.0                           0.0
# 8037                                     0.0                           0.0
# 8079                                     0.0                           0.0
# 8086                                     0.0                           0.0
# ...                                      ...                           ...
# 61625                                    0.0                           0.0
# 61631                                    0.0                           0.0
# 61640                                    0.0                           0.0
# 61643                                    0.0                           0.0
# 61661                                    0.0                           0.0
#
#              Wrap Wick Bold Ta Pronto 300g  Xarope Groselha Asteca 500ml  \
# customer_id
# 7927                                   0.0                           0.0
# 7952                                   0.0                           0.0
# 8037                                   0.0                           0.0
# 8079                                   0.0                           0.0
# 8086                                   0.0                           1.0
# ...                                    ...                           ...
# 61625                                  0.0                           0.0
# 61631                                  0.0                           0.0
# 61640                                  0.0                           0.0
# 61643                                  0.0                           0.0
# 61661                                  0.0                           0.0
#
#              Xarope Groselha Asteca 900ml  Xarope Groselha Primor 1l  \
# customer_id
# 7927                                  0.0                        0.0
# 7952                                  0.0                        0.0
# 8037                                  0.0                        0.0
# 8079                                  0.0                        0.0
# 8086                                  0.0                        0.0
# ...                                   ...                        ...
# 61625                                 0.0                        0.0
# 61631                                 0.0                        0.0
# 61640                                 0.0                        0.0
# 61643                                 0.0                        0.0
# 61661                                 0.0                        0.0
#
#              Xicara Cha Duralex Astral Un  Yakissoba Frango Kg  \
# customer_id
# 7927                                  0.0                  0.0
# 7952                                  0.0                  0.0
# 8037                                  0.0                  0.0
# 8079                                  0.0                  0.0
# 8086                                  0.0                  0.0
# ...                                   ...                  ...
# 61625                                 0.0                  0.0
# 61631                                 0.0                  0.0
# 61640                                 0.0                  0.0
# 61643                                 0.0                  0.0
# 61661                                 0.0                  0.0
#
#              Yakissoba Sadia 600g
# customer_id
# 7927                          0.0
# 7952                          0.0
# 8037                          0.0
# 8079                          0.0
# 8086                          0.0
# ...                           ...
# 61625                         0.0
# 61631                         0.0
# 61640                         0.0
# 61643                         0.0
# 61661                         0.0
#
# [1001 rows x 5579 columns]

# %%
# analisando a correlação dos produtos
correlation = descricao_por_id.corr()
correlation
# Out:
#                                 Abacate Kg  Abacaxi Calda Ole Rodelas 400g  \
# Abacate Kg                        1.000000                       -0.000051
# Abacaxi Calda Ole Rodelas 400g   -0.000051                        1.000000
# Abacaxi Calda Predilecta 400g     0.021790                       -0.003979
# Abacaxi Hawai Un                  0.262331                        0.015087
# Abacaxi Pedaco Kg                 0.008511                       -0.008952
# ...                                    ...                             ...
# Xarope Groselha Asteca 900ml     -0.020532                       -0.009341
# Xarope Groselha Primor 1l        -0.006911                       -0.003144
# Xicara Cha Duralex Astral Un     -0.006911                       -0.003144
# Yakissoba Frango Kg              -0.006911                       -0.003144
# Yakissoba Sadia 600g             -0.010426                       -0.004743
#
#                                 Abacaxi Calda Predilecta 400g  \
# Abacate Kg                                           0.021790
# Abacaxi Calda Ole Rodelas 400g                      -0.003979
# Abacaxi Calda Predilecta 400g                        1.000000
# Abacaxi Hawai Un                                    -0.008046
# Abacaxi Pedaco Kg                                   -0.003602
# ...                                                       ...
# Xarope Groselha Asteca 900ml                        -0.003759
# Xarope Groselha Primor 1l                           -0.001265
# Xicara Cha Duralex Astral Un                        -0.001265
# Yakissoba Frango Kg                                 -0.001265
# Yakissoba Sadia 600g                                -0.001909
#
#                                 Abacaxi Hawai Un  Abacaxi Pedaco Kg  \
# Abacate Kg                              0.262331           0.008511
# Abacaxi Calda Ole Rodelas 400g          0.015087          -0.008952
# Abacaxi Calda Predilecta 400g          -0.008046          -0.003602
# Abacaxi Hawai Un                        1.000000           0.016103
# Abacaxi Pedaco Kg                       0.016103           1.000000
# ...                                          ...                ...
# Xarope Groselha Asteca 900ml            0.008406          -0.008458
# Xarope Groselha Primor 1l              -0.006359          -0.002847
# Xicara Cha Duralex Astral Un            0.032691          -0.002847
# Yakissoba Frango Kg                    -0.006359          -0.002847
# Yakissoba Sadia 600g                    0.002189          -0.004295
#
#                                 Abacaxi Perola Un  Abacaxi Proc Kg  \
# Abacate Kg                               0.626934        -0.006911
# Abacaxi Calda Ole Rodelas 400g          -0.017102        -0.003144
# Abacaxi Calda Predilecta 400g           -0.010818        -0.001265
# Abacaxi Hawai Un                         0.257414        -0.006359
# Abacaxi Pedaco Kg                        0.061502         0.435573
# ...                                           ...              ...
# Xarope Groselha Asteca 900ml             0.012657        -0.002971
# Xarope Groselha Primor 1l               -0.008550        -0.001000
# Xicara Cha Duralex Astral Un             0.078559        -0.001000
# Yakissoba Frango Kg                      0.013227        -0.001000
# Yakissoba Sadia 600g                     0.006813        -0.001509
#
#                                 Abobora Cabotia Cort Kg  \
# Abacate Kg                                     0.251832
# Abacaxi Calda Ole Rodelas 400g                 0.038672
# Abacaxi Calda Predilecta 400g                 -0.008626
# Abacaxi Hawai Un                               0.108033
# Abacaxi Pedaco Kg                              0.127112
# ...                                                 ...
# Xarope Groselha Asteca 900ml                   0.038208
# Xarope Groselha Primor 1l                     -0.006818
# Xicara Cha Duralex Astral Un                  -0.006818
# Yakissoba Frango Kg                           -0.006818
# Yakissoba Sadia 600g                          -0.010285
#
#                                 Abobora Cabotia Int Kg  \
# Abacate Kg                                    0.290721
# Abacaxi Calda Ole Rodelas 400g                0.039878
# Abacaxi Calda Predilecta 400g                -0.009329
# Abacaxi Hawai Un                              0.131497
# Abacaxi Pedaco Kg                            -0.003422
# ...                                                ...
# Xarope Groselha Asteca 900ml                  0.006134
# Xarope Groselha Primor 1l                    -0.007373
# Xicara Cha Duralex Astral Un                 -0.007373
# Yakissoba Frango Kg                          -0.007373
# Yakissoba Sadia 600g                         -0.011122
#
#                                 Abobora Madura Seca Cort Kg  ...  \
# Abacate Kg                                         0.169026  ...
# Abacaxi Calda Ole Rodelas 400g                     0.011110  ...
# Abacaxi Calda Predilecta 400g                     -0.007153  ...
# Abacaxi Hawai Un                                   0.052692  ...
# Abacaxi Pedaco Kg                                 -0.006706  ...
# ...                                                     ...  ...
# Xarope Groselha Asteca 900ml                      -0.016796  ...
# Xarope Groselha Primor 1l                         -0.005654  ...
# Xicara Cha Duralex Astral Un                      -0.005654  ...
# Yakissoba Frango Kg                               -0.005654  ...
# Yakissoba Sadia 600g                              -0.008528  ...
#
#                                 Whisky Johnnie Walker 1l  \
# Abacate Kg                                     -0.009779
# Abacaxi Calda Ole Rodelas 400g                  0.154604
# Abacaxi Calda Predilecta 400g                  -0.001790
# Abacaxi Hawai Un                                0.018629
# Abacaxi Pedaco Kg                              -0.004028
# ...                                                  ...
# Xarope Groselha Asteca 900ml                   -0.004204
# Xarope Groselha Primor 1l                      -0.001415
# Xicara Cha Duralex Astral Un                   -0.001415
# Yakissoba Frango Kg                            -0.001415
# Yakissoba Sadia 600g                           -0.002134
#
#                                 Whisky Natu Nobilis Nacional 1l  \
# Abacate Kg                                            -0.006911
# Abacaxi Calda Ole Rodelas 400g                        -0.003144
# Abacaxi Calda Predilecta 400g                         -0.001265
# Abacaxi Hawai Un                                      -0.006359
# Abacaxi Pedaco Kg                                     -0.002847
# ...                                                         ...
# Xarope Groselha Asteca 900ml                          -0.002971
# Xarope Groselha Primor 1l                             -0.001000
# Xicara Cha Duralex Astral Un                          -0.001000
# Yakissoba Frango Kg                                   -0.001000
# Yakissoba Sadia 600g                                  -0.001509
#
#                                 Whisky Old Eight Nacional 1l  \
# Abacate Kg                                         -0.009779
# Abacaxi Calda Ole Rodelas 400g                     -0.004449
# Abacaxi Calda Predilecta 400g                      -0.001790
# Abacaxi Hawai Un                                   -0.008997
# Abacaxi Pedaco Kg                                  -0.004028
# ...                                                      ...
# Xarope Groselha Asteca 900ml                       -0.004204
# Xarope Groselha Primor 1l                          -0.001415
# Xicara Cha Duralex Astral Un                       -0.001415
# Yakissoba Frango Kg                                -0.001415
# Yakissoba Sadia 600g                               -0.002134
#
#                                 Wrap Wick Bold Ta Pronto 300g  \
# Abacate Kg                                           0.034495
# Abacaxi Calda Ole Rodelas 400g                      -0.006298
# Abacaxi Calda Predilecta 400g                       -0.002534
# Abacaxi Hawai Un                                     0.026372
# Abacaxi Pedaco Kg                                   -0.005702
# ...                                                       ...
# Xarope Groselha Asteca 900ml                        -0.005951
# Xarope Groselha Primor 1l                           -0.002003
# Xicara Cha Duralex Astral Un                        -0.002003
# Yakissoba Frango Kg                                  0.499249
# Yakissoba Sadia 600g                                -0.003022
#
#                                 Xarope Groselha Asteca 500ml  \
# Abacate Kg                                          0.004302
# Abacaxi Calda Ole Rodelas 400g                      0.041408
# Abacaxi Calda Predilecta 400g                       0.070327
# Abacaxi Hawai Un                                   -0.005609
# Abacaxi Pedaco Kg                                   0.093219
# ...                                                      ...
# Xarope Groselha Asteca 900ml                        0.071736
# Xarope Groselha Primor 1l                          -0.003796
# Xicara Cha Duralex Astral Un                       -0.003796
# Yakissoba Frango Kg                                -0.003796
# Yakissoba Sadia 600g                               -0.005727
#
#                                 Xarope Groselha Asteca 900ml  \
# Abacate Kg                                         -0.020532
# Abacaxi Calda Ole Rodelas 400g                     -0.009341
# Abacaxi Calda Predilecta 400g                      -0.003759
# Abacaxi Hawai Un                                    0.008406
# Abacaxi Pedaco Kg                                  -0.008458
# ...                                                      ...
# Xarope Groselha Asteca 900ml                        1.000000
# Xarope Groselha Primor 1l                          -0.002971
# Xicara Cha Duralex Astral Un                       -0.002971
# Yakissoba Frango Kg                                -0.002971
# Yakissoba Sadia 600g                                0.153851
#
#                                 Xarope Groselha Primor 1l  \
# Abacate Kg                                      -0.006911
# Abacaxi Calda Ole Rodelas 400g                  -0.003144
# Abacaxi Calda Predilecta 400g                   -0.001265
# Abacaxi Hawai Un                                -0.006359
# Abacaxi Pedaco Kg                               -0.002847
# ...                                                   ...
# Xarope Groselha Asteca 900ml                    -0.002971
# Xarope Groselha Primor 1l                        1.000000
# Xicara Cha Duralex Astral Un                    -0.001000
# Yakissoba Frango Kg                             -0.001000
# Yakissoba Sadia 600g                            -0.001509
#
#                                 Xicara Cha Duralex Astral Un  \
# Abacate Kg                                         -0.006911
# Abacaxi Calda Ole Rodelas 400g                     -0.003144
# Abacaxi Calda Predilecta 400g                      -0.001265
# Abacaxi Hawai Un                                    0.032691
# Abacaxi Pedaco Kg                                  -0.002847
# ...                                                      ...
# Xarope Groselha Asteca 900ml                       -0.002971
# Xarope Groselha Primor 1l                          -0.001000
# Xicara Cha Duralex Astral Un                        1.000000
# Yakissoba Frango Kg                                -0.001000
# Yakissoba Sadia 600g                               -0.001509
#
#                                 Yakissoba Frango Kg  Yakissoba Sadia 600g
# Abacate Kg                                -0.006911             -0.010426
# Abacaxi Calda Ole Rodelas 400g            -0.003144             -0.004743
# Abacaxi Calda Predilecta 400g             -0.001265             -0.001909
# Abacaxi Hawai Un                          -0.006359              0.002189
# Abacaxi Pedaco Kg                         -0.002847             -0.004295
# ...                                             ...                   ...
# Xarope Groselha Asteca 900ml              -0.002971              0.153851
# Xarope Groselha Primor 1l                 -0.001000             -0.001509
# Xicara Cha Duralex Astral Un              -0.001000             -0.001509
# Yakissoba Frango Kg                        1.000000             -0.001509
# Yakissoba Sadia 600g                      -0.001509              1.000000
#
# [5579 rows x 5579 columns]

# %%
# maiores correlações tirando as duplicatas
maiores_corrs = correlation.unstack().sort_values(ascending=False)[20:]
maiores_corrs
# Out:
# name                          name
# Suco Do Bem Vd 1l             Secante P/Maq Louca Finish 250ml     1.000000
# Limpa Couro Proauto Hid 150g  Suco Do Bem Vd 1l                    1.000000
# Suco Do Bem Vd 1l             Suco Uva Pietro Felice 1l            1.000000
#                               Vaso Manjericao Roxo Un              1.000000
#                               Vinho Casa Perini Solidario 750ml    1.000000
#                                                                      ...
# Lava Louca Liq Ype 500ml      Marmitex Barracao 2ª Op             -0.078972
# Marmitex Barracao 10ª Op      Mac Basilar Semolado 500g           -0.080733
# Mac Basilar Semolado 500g     Marmitex Barracao 10ª Op            -0.080733
# Cr Leite Jussara Tp 200g      Marmitex Barracao 2ª Op             -0.085541
# Marmitex Barracao 2ª Op       Cr Leite Jussara Tp 200g            -0.085541
# Length: 31125221, dtype: float64

# %%
prod_menos = maiores_corrs.loc[maiores_corrs.values < 1.000000]
print('Produtos menos vendidos:\n', prod_menos )
# Out:
# Produtos menos vendidos:
#  name                                name
# Boleira Plasutil Decora Retangular  Pote Hermet Santana 865ml             1.000000
# Conj Prato Nadir Diamante Fundo Un  Pote Hermet Santana 865ml             1.000000
# Pote Hermet Santana 865ml           Boleira Plasutil Decora Retangular    1.000000
#                                     Panceta Suina Fresca Fat Kg           1.000000
# Panceta Suina Fresca Fat Kg         Pote Hermet Santana 865ml             1.000000
#                                                                             ...
# Lava Louca Liq Ype 500ml            Marmitex Barracao 2ª Op              -0.078972
# Marmitex Barracao 10ª Op            Mac Basilar Semolado 500g            -0.080733
# Mac Basilar Semolado 500g           Marmitex Barracao 10ª Op             -0.080733
# Cr Leite Jussara Tp 200g            Marmitex Barracao 2ª Op              -0.085541
# Marmitex Barracao 2ª Op             Cr Leite Jussara Tp 200g             -0.085541
# Length: 31116632, dtype: float64

# %%
# Out:
# name                                name
# Boleira Plasutil Decora Retangular  Pote Hermet Santana 865ml             1.000000
# Conj Prato Nadir Diamante Fundo Un  Pote Hermet Santana 865ml             1.000000
# Pote Hermet Santana 865ml           Boleira Plasutil Decora Retangular    1.000000
#                                     Panceta Suina Fresca Fat Kg           1.000000
# Panceta Suina Fresca Fat Kg         Pote Hermet Santana 865ml             1.000000
#                                                                             ...
# Marmitex Barracao 2ª Op             Lava Louca Liq Ype 500ml             -0.078972
# Mac Basilar Semolado 500g           Marmitex Barracao 10ª Op             -0.080733
# Marmitex Barracao 10ª Op            Mac Basilar Semolado 500g            -0.080733
# Cr Leite Jussara Tp 200g            Marmitex Barracao 2ª Op              -0.085541
# Marmitex Barracao 2ª Op             Cr Leite Jussara Tp 200g             -0.085541
# Length: 31116632, dtype: float64

# %%
# Removendo dados duplicados
maiores_corrs = maiores_corrs.head(10).drop_duplicates()
maiores_corrs
# Out:
# Ambrosia Port Res De Minas 620g  Pano U.Geral s Brite C/2    1.0
# dtype: float64

# %%
#obter as combinações
combinacoes = []
for i in range(5):
    combinacoes.append(maiores_corrs.index[i][0] + " + " + maiores_corrs.index[i][1])
#resultado da lista
print(combinacoes)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-646d2552d13c> in <module>()
#       2 combinacoes = []
#       3 for i in range(5):
# ----> 4     combinacoes.append(maiores_corrs.index[i][0] + " + " + maiores_corrs.index[i][1])
#       5 #resultado da lista
#       6 print(combinacoes)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in __getitem__(self, key)
#    1931             retval = []
#    1932             for lev, level_codes in zip(self.levels, self.codes):
# -> 1933                 if level_codes[key] == -1:
#    1934                     retval.append(np.nan)
#    1935                 else:
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
